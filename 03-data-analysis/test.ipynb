# %%
print("hello")
# Out:
# Running cells with 'venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/maziidev/Documents/mazii-foundry/01-python-basics/venv/bin/python -m pip install ipykernel -U --force-reinstall'
